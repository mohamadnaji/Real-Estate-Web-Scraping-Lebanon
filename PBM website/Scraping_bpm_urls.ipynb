# %%
import requests
import pandas as pd
import os
import concurrent.futures
from bs4 import BeautifulSoup
from google.colab import files
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Function to scrape URLs with a specific prefix
def scrape_urls_with_prefix(url):
    # Send a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200 and url == response.url:
        # Parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all 'a' tags
        a_tags = soup.find_all('a', class_="h-100")
        if not a_tags:
            print(f"No 'a' tags found on page {url}")
            return None
        # Extract the href attribute of each a tag that starts with the specified prefix
        filtered_urls = [a.get('href') for a in a_tags if a.get('href') and a.get('href')]
        print(f"Scraped {len(filtered_urls)} URLs from {url}")
        return set(filtered_urls)
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return None

# %%
def scrape_urls(initial_url):
    urls = set()
    idx = 2
    while True:
        # Scrape URLs with the specified prefix
        print(f'Scraping page {idx}')
        new_urls = scrape_urls_with_prefix(f'{initial_url}?page={idx}')
        if new_urls is None:
            break
        urls.update(new_urls)
        idx += 1
    return urls

# %%
def save_urls_to_csv(urls, csv_file_path):

    urls = scrape_urls(urls)
    print(f'Number of urls: {len(urls)}')

    # Convert set to list
    data_list = list(urls)

    # Create a DataFrame from the list
    df = pd.DataFrame(data_list, columns=['URL'])

    # Save the DataFrame to an Excel file
    df.to_csv(csv_file_path, index=False)

# %%
url_rent = f'https://pbm-leb.com/en/rent'
csv_file_path_rent = '/content/drive/MyDrive/M2 final project/PBM website/urls_to_be_scraped_rent.csv'

url_sale = f'https://pbm-leb.com/en/search'
csv_file_path_sale = '/content/drive/MyDrive/M2 final project/PBM website/urls_to_be_scraped_sale.csv'

# %%
save_urls_to_csv(url_rent, csv_file_path_rent)
save_urls_to_csv(url_sale, csv_file_path_sale)
# Out:
# Scraping page 2
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=2
# Scraping page 3
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=3
# Scraping page 4
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=4
# Scraping page 5
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=5
# Scraping page 6
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=6
# Scraping page 7
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=7
# Scraping page 8
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=8
# Scraping page 9
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=9
# Scraping page 10
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=10
# Scraping page 11
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=11
# Scraping page 12
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=12
# Scraping page 13
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=13
# Scraping page 14
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=14
# Scraping page 15
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=15
# Scraping page 16
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=16
# Scraping page 17
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=17
# Scraping page 18
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=18
# Scraping page 19
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=19
# Scraping page 20
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=20
# Scraping page 21
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=21
# Scraping page 22
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=22
# Scraping page 23
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=23
# Scraping page 24
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=24
# Scraping page 25
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=25
# Scraping page 26
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=26
# Scraping page 27
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=27
# Scraping page 28
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=28
# Scraping page 29
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=29
# Scraping page 30
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=30
# Scraping page 31
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=31
# Scraping page 32
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=32
# Scraping page 33
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=33
# Scraping page 34
# Scraped 8 URLs from https://pbm-leb.com/en/rent?page=34
# Scraping page 35
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=35
# Scraping page 36
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=36
# Scraping page 37
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=37
# Scraping page 38
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=38
# Scraping page 39
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=39
# Scraping page 40
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=40
# Scraping page 41
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=41
# Scraping page 42
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=42
# Scraping page 43
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=43
# Scraping page 44
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=44
# Scraping page 45
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=45
# Scraping page 46
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=46
# Scraping page 47
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=47
# Scraping page 48
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=48
# Scraping page 49
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=49
# Scraping page 50
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=50
# Scraping page 51
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=51
# Scraping page 52
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=52
# Scraping page 53
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=53
# Scraping page 54
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=54
# Scraping page 55
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=55
# Scraping page 56
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=56
# Scraping page 57
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=57
# Scraping page 58
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=58
# Scraping page 59
# Scraped 7 URLs from https://pbm-leb.com/en/rent?page=59
# Scraping page 60
# Scraped 6 URLs from https://pbm-leb.com/en/rent?page=60
# Scraping page 61
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=61
# Scraping page 62
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=62
# Scraping page 63
# Scraped 8 URLs from https://pbm-leb.com/en/rent?page=63
# Scraping page 64
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=64
# Scraping page 65
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=65
# Scraping page 66
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=66
# Scraping page 67
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=67
# Scraping page 68
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=68
# Scraping page 69
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=69
# Scraping page 70
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=70
# Scraping page 71
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=71
# Scraping page 72
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=72
# Scraping page 73
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=73
# Scraping page 74
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=74
# Scraping page 75
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=75
# Scraping page 76
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=76
# Scraping page 77
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=77
# Scraping page 78
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=78
# Scraping page 79
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=79
# Scraping page 80
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=80
# Scraping page 81
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=81
# Scraping page 82
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=82
# Scraping page 83
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=83
# Scraping page 84
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=84
# Scraping page 85
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=85
# Scraping page 86
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=86
# Scraping page 87
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=87
# Scraping page 88
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=88
# Scraping page 89
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=89
# Scraping page 90
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=90
# Scraping page 91
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=91
# Scraping page 92
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=92
# Scraping page 93
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=93
# Scraping page 94
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=94
# Scraping page 95
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=95
# Scraping page 96
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=96
# Scraping page 97
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=97
# Scraping page 98
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=98
# Scraping page 99
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=99
# Scraping page 100
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=100
# Scraping page 101
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=101
# Scraping page 102
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=102
# Scraping page 103
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=103
# Scraping page 104
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=104
# Scraping page 105
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=105
# Scraping page 106
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=106
# Scraping page 107
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=107
# Scraping page 108
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=108
# Scraping page 109
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=109
# Scraping page 110
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=110
# Scraping page 111
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=111
# Scraping page 112
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=112
# Scraping page 113
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=113
# Scraping page 114
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=114
# Scraping page 115
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=115
# Scraping page 116
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=116
# Scraping page 117
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=117
# Scraping page 118
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=118
# Scraping page 119
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=119
# Scraping page 120
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=120
# Scraping page 121
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=121
# Scraping page 122
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=122
# Scraping page 123
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=123
# Scraping page 124
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=124
# Scraping page 125
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=125
# Scraping page 126
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=126
# Scraping page 127
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=127
# Scraping page 128
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=128
# Scraping page 129
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=129
# Scraping page 130
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=130
# Scraping page 131
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=131
# Scraping page 132
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=132
# Scraping page 133
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=133
# Scraping page 134
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=134
# Scraping page 135
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=135
# Scraping page 136
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=136
# Scraping page 137
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=137
# Scraping page 138
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=138
# Scraping page 139
# Scraped 8 URLs from https://pbm-leb.com/en/rent?page=139
# Scraping page 140
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=140
# Scraping page 141
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=141
# Scraping page 142
# Scraped 9 URLs from https://pbm-leb.com/en/rent?page=142
# Scraping page 143
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=143
# Scraping page 144
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page=144
# Scraping page 145
# Scraped 10 URLs from https://pbm-leb.com/en/rent?page